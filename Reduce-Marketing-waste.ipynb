# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("train.csv")
data.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    320506$      2067263.7$       2020-03-29  Product_2
# 1     39488$       240876.8$       2019-07-10  Product_2
# 2    359392$      2407926.4$       2019-07-27  Product_1
# 3     76774$       468321.4$       2021-01-30  Product_2
# 4    483896$             NaN       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# 1          892-938-9493  500 Million - 1 Billion    Category 4  ...
# ...

# %%
print("Shape of our data set ",data.shape)
# Out:
# Shape of our data set  (7007, 23)

# %%
#check data type of all the coulmns
data.dtypes
# Out:
# Deal_title                object
# Lead_name                 object
# Industry                  object
# Deal_value                object
# Weighted_amount           object
# Date_of_creation          object
# Pitch                     object
# Contact_no                object
# Lead_revenue              object
# Fund_category             object
# Geography                 object
# Location                  object
# POC_name                  object
# Designation               object
# Lead_POC_email            object
# Hiring_candidate_role     object
# Lead_source               object
# Level_of_meeting          object
# Last_lead_update          object
# Internal_POC              object
# Resource                  object
# Internal_rating            int64
# Success_probability      float64
# dtype: object

# %%
#check for null values
data.isnull().sum()
# Out:
# Deal_title                 0
# Lead_name                  0
# Industry                   1
# Deal_value                51
# Weighted_amount          525
# Date_of_creation           0
# Pitch                      0
# Contact_no                 0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# POC_name                   8
# Designation                0
# Lead_POC_email             0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %% [markdown]
# # First we will treat all missing values

# %%
#check null value 4653 Title232C0
data[data["Industry"].isnull()]
# Out:
#       Deal_title                                  Lead_name Industry  \
# 4653  Title232C0  Valenzuela, Williamson and Henry and Sons      NaN
#
#      Deal_value Weighted_amount Date_of_creation      Pitch    Contact_no  \
# 4653    209418$      1266978.9$       2020-12-15  Product_2  737.346.8367
#
#           Lead_revenue Fund_category  ...           Designation  \
# 4653  50 - 100 Million    Category 4  ...  SVP/General Counsel
#
#                   Lead_POC_email Hiring_candidate_role    Lead_source  \
# 4653  johnathanle@valenzuela.com   Landscape architect  Contact Email
#
#      Level_of_meeting Last_lead_update    Internal_POC Resource  \
# 4653          Level 1      2 days back  Hameier,Kurt E       No
#
#      Internal_rating Success_probability
# 4653               3                56.6
#
# [1 rows x 23 columns]

# %%
# task 1 Fill missing value in Industry
data["Industry"] = data["Industry"].fillna((data["Industry"].mode()[0]))

# %%
# Deal_value consist of 51 missing values we will impute mean over missing values.
data[data["Deal_value"].isnull()]
# Out:
#       Deal_title                                 Lead_name  \
# 169   TitleKXH1L               Turner, Green and Brown Ltd
# 381   TitleBV4VN                 Perez, Lopez and Lara Inc
# 448   TitleMUK48            Harding, Burke and Price Group
# 469   TitleXSNO6                      Marshall-Johnson LLC
# 519   TitleK69MY                     Campbell Ltd and Sons
# 1016  TitleXD5MP                  Burke, Hart and Hale PLC
# 1148  TitleWB44B                    Ruiz-Mcdaniel and Sons
# 1246  Title6X0QM           Alvarez, Cooper and Griffin Inc
# 1328  TitleDUHSS                      Ramirez-Figueroa LLC
# 1587  TitleMPX29                  Walker-Browning and Sons
# 1599  Title27F7I                              Duke Ltd LLC
# 1626  TitleO80HC                        Smith Ltd and Sons
# 1636  TitleNSRAK                  Wood, Smith and Rice LLC
# 1651  TitleSGTCT           Mccormick, Norris and Clark Ltd
# 1849  Title8XSJJ        Matthews, Fields and Barnett Group
# ...

# %% [markdown]
# To fill missing value in Deal_Value column we first need to conver it to integer. For that we have to remove that $ sign first.

# %%
data["Deal_value"]= data["Deal_value"].str.replace("$","")
data.Deal_value.head()
# Out:
# <ipython-input-39-e80ee3952f61>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data["Deal_value"]= data["Deal_value"].str.replace("$","")
# 0    320506
# 1     39488
# 2    359392
# 3     76774
# 4    483896
# Name: Deal_value, dtype: object

# %%
#converting Deal_Value to numeric
data["Deal_value"] = pd.to_numeric(data["Deal_value"])
# Out:
# 0    320506.0
# 1     39488.0
# 2    359392.0
# 3     76774.0
# 4    483896.0
# Name: Deal_value, dtype: float64

# %%
#imputing missing value in Deal_value
data["Deal_value"] = data["Deal_value"].fillna(data["Deal_value"].mean())

# %%
#Similarly for Weighted Amount we have to remove the $ sign first then impute the missing values with mean 
data[data["Weighted_amount"].isnull()]
# Out:
#       Deal_title                        Lead_name                   Industry  \
# 4     Title904GV                 Lee and Sons PLC         Financial Services
# 13    TitleNQKU6           Fowler-Medina and Sons                      Banks
# 17    TitleEWIQD                Rodriguez Inc LLC                   Software
# 23    TitleO0W9A                   Meza-Myers Inc                       REIT
# 33    TitleQ5K7M   Petersen, Lindsey and Wong LLC  Automotive/Transportation
# ...          ...                              ...                        ...
# 6971  Title6SSU1   Cortez, Manning and Morris LLC          Hospitals/Clinics
# 6975  Title5441H                Whitehead LLC PLC         Financial Services
# 6983  TitleVDKHN                  Henson-Soto Ltd      Professional Services
# 6990  Title4H88W  Miranda, Mccoy and Mccarthy Inc                  Insurance
# 7004  TitleF1FWY                Romero-Juarez PLC             Semiconductors
#
# ...

# %%
# removing the $ sign
data["Weighted_amount"]= data["Weighted_amount"].str.replace("$","")
# Out:
# <ipython-input-48-826d9348be3e>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data["Weighted_amount"]= data["Weighted_amount"].str.replace("$","")

# %%
# now conver the Weighted_amount to numeric and then impute missing values using mean()
#converting Weighted_amount to numeric
data["Weighted_amount"] = pd.to_numeric(data["Weighted_amount"])
data["Weighted_amount"] = data["Weighted_amount"].fillna(data["Weighted_amount"].mean())

# %%
#data.head()
#data[data["Deal_title"]=="TitleKXH1L"]

# %%
#converting the Date_of_creation to date time
data["Date_of_creation"] = pd.to_datetime(data["Date_of_creation"])
data.Date_of_creation.dtype
# Out:
# dtype('<M8[ns]')

# %%
#to get all columns
pd.set_option("display.max_columns",25)

# %%
data[data["Geography"].isnull()].head()
# Out:
#     Deal_title                          Lead_name  \
# 6   TitleOZQRY            Williamson LLC and Sons
# 10  TitleP5EAQ               Bradley-Willis Group
# 13  TitleNQKU6             Fowler-Medina and Sons
# 16  TitleBZ8I3                     Hull Group Ltd
# 27  TitleWKMYP  Maldonado, Doyle and Patton Group
#
#                           Industry  Deal_value  Weighted_amount  \
# 6                            Banks    384356.0     2.709710e+06
# 10  Healthcare Facilities/Services    311125.0     1.851194e+06
# 13                           Banks    487351.0     1.569884e+06
# 16          Other Investment Firms    390309.0     2.458947e+06
# 27                        Trucking    380817.0     2.513392e+06
#
#    Date_of_creation      Pitch             Contact_no  \
# 6        2019-11-20  Product_2          (881)077-4692
# 10       2020-01-30  Product_1      466.038.3610x6981
# 13       2020-04-25  Product_1  001-149-287-9330x6974
# ...

# %%
#we will replace the geopgraphy value by mode 
data["Geography"] = data["Geography"].fillna((data["Geography"].mode()[0]))

# %%
data[data["Location"].isnull()]
# Out:
#       Deal_title                         Lead_name                   Industry  \
# 545   TitleY3XZP                 Ramirez-Grant Inc  Investment Bank/Brokerage
# 810   TitleE0MD4                  Anderson Ltd PLC                       REIT
# 1597  TitleX2NTQ   Flores, Rodriguez and Rubio LLC                  Insurance
# 1623  Title4AI1N    Bryant, Powell and Benitez Inc                      Banks
# 1698  TitleT9KKE                     Lopez LLC Inc         Telecom Consulting
# 1901  TitleQF35M                  Baxter-Kelly Inc  Investment Bank/Brokerage
# 3466  TitleHI98X       Bowen, Nolan and Thomas Inc   Architecture/Engineering
# 4201  TitleK42F3  Price, Anderson and Robinson PLC         Other Biz Services
# 5222  TitleOSYEE                  Wilson-Young LLC                   Staffing
# 5675  Title9V907                   Vaughan Ltd PLC         Financial Services
# 6862  Title70QKM                Stout and Sons Ltd                      Banks
#
# ...

# %%
# The Location feature consist of around 11 missing values with region as USA and no missing values in the India region.
#Lets check the most common location is the USA region. 
data2=data[data["Geography"]=="USA"]
data2.Location.mode()
# Out:
# 0    Panama City, FL
# dtype: object

# %%
#now replace the missing value in the Location column where region is USA with Panama City, FL

# %%
data["Location"] = data["Location"].fillna((data2.Location.mode()[0]))

# %%
#data[data["Deal_title"]=="TitleY3XZP"]
#cross check the values

# %%
# now we have missing values in the POC_name column, Replace it with mode
data.POC_name.mode()[0]
# Out:
# 'pooja'

# %%
data[data["POC_name"].isnull()].head()
# Out:
#       Deal_title                          Lead_name         Industry  \
# 489   TitleS2D23  Martinez, Gutierrez and Knapp PLC        Insurance
# 599   TitleST3S0      Anderson, Buckley and Lee LLC        Insurance
# 1862  TitleDQJEL                  Armstrong Inc LLC            Banks
# 2008  Title612IP      King, Davenport and James LLC  Servers/Storage
# 2053  TitleEPQ2Q                   Lozano-Clark Inc            Banks
#
#       Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 489     209984.0       1186409.60       2019-06-07  Product_2
# 599     326899.0       2043118.75       2019-07-04  Product_1
# 1862    457421.0       2813139.15       2019-06-04  Product_2
# 2008    118302.0        727557.30       2020-03-10  Product_2
# 2053     90309.0        546369.45       2021-02-07  Product_2
#
#                Contact_no             Lead_revenue Fund_category Geography  \
# 489          358-063-2204         50 - 100 Million    Category 3     India
# ...

# %%
#replace  missing value in POC_name
data["POC_name"] = data["POC_name"].fillna((data.POC_name.mode()[0]))

# %%
#filling 633 missing values in Last_lead_update with mode value
data.Last_lead_update.mode()[0]
# Out:
# 'Following up but lead not responding'

# %%
data[data["Last_lead_update"].isnull()].head()
# Out:
#     Deal_title                           Lead_name            Industry  \
# 12  TitleOGCTY                    Weaver Group Inc  Biotech/Healthcare
# 35  TitleLLTG0                  Hughes-Johnson PLC   Constr - Supplies
# 48  TitleZITZC                   Bass and Sons Inc               Banks
# 51  Title190KW  Norton, Edwards and Chung and Sons        Associations
# 65  Title8W9AG                  Howe-Cruz and Sons           Insurance
#
#     Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 12    222331.0        1400685.3       2020-03-27  Product_2
# 35    216892.0        1344730.4       2019-07-30  Product_1
# 48    376485.0        2560098.0       2020-05-02  Product_2
# 51    457274.0        2972281.0       2019-10-25  Product_2
# 65     58778.0         405568.2       2020-02-17  Product_2
#
#               Contact_no             Lead_revenue Fund_category Geography  \
# 12          262-729-7106        100 - 500 Million    Category 2       USA
# ...

# %%
data.Last_lead_update.mode()[0]
# Out:
# 'Following up but lead not responding'

# %%
#replace  missing value in Last_lead_update
data["Last_lead_update"] = data["Last_lead_update"].fillna((data.Last_lead_update.mode()[0]))

# %%
#check missing values in Resource column
data.Resource.isnull().sum()
# Out:
# 149

# %%
data[data["Resource"].isnull()].head()
# Out:
#      Deal_title                      Lead_name  \
# 0    TitleM5DZY  Davis, Perkins and Bishop Inc
# 6    TitleOZQRY        Williamson LLC and Sons
# 111  TitleNP5Z6       Salinas-Parsons and Sons
# 145  Title6BJEK                Foley-Berry PLC
# 189  Title3ORBL                Ramirez LLC Ltd
#
#                            Industry  Deal_value  Weighted_amount  \
# 0                       Restaurants    320506.0     2.067264e+06
# 6                             Banks    384356.0     2.709710e+06
# 111                   Hotels/Motels    435551.0     2.417308e+06
# 145  Healthcare Facilities/Services    283482.0     1.658370e+06
# 189              Other Biz Services    321223.0     1.569884e+06
#
#     Date_of_creation      Pitch              Contact_no  \
# 0         2020-03-29  Product_2            607.447.7883
# 6         2019-11-20  Product_2           (881)077-4692
# 111       2020-06-02  Product_1            264-257-8983
# 145       2020-09-24  Product_2  001-001-743-9237x61783
# ...

# %%
#most occuring value of Resource Category
data["Resource"].mode()[0]
# Out:
# 'No'

# %%
#replace  missing value in Resource
data["Resource"] = data["Resource"].fillna((data["Resource"].mode()[0]))

# %% [markdown]
# # # Now all the missing values treatment is over. Next we have to encode the categorical column.

# %%
# Save the file as processed File version 1 for a safer side.

# %%
data.to_csv("Processed_V1.csv", index=False)

# %%
#data[data["Success_probability"]>100].count()

# %% [markdown]
# # Starting with encoding the categorical values.

# %%
from sklearn.preprocessing import LabelEncoder
lab_encod= LabelEncoder()

# %%
#lets start with encoding.
data.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#    Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 0    320506.0     2.067264e+06       2020-03-29  Product_2
# 1     39488.0     2.408768e+05       2019-07-10  Product_2
# 2    359392.0     2.407926e+06       2019-07-27  Product_1
# 3     76774.0     4.683214e+05       2021-01-30  Product_2
# 4    483896.0     1.569884e+06       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category Geography  \
# 0          607.447.7883         50 - 100 Million    Category 2       USA
# ...

# %%
# Starting from first variable.
#Lead_name consist of all unique values.

# %%
data2.head()
# Out:
#    Deal_title                         Lead_name                  Industry  \
# 0  TitleM5DZY     Davis, Perkins and Bishop Inc               Restaurants
# 2  TitleFXSDN             Carter-Henry and Sons         Hospitals/Clinics
# 3  TitlePSK4Y                    Garcia Ltd Ltd               Real Estate
# 6  TitleOZQRY           Williamson LLC and Sons                     Banks
# 7  TitleV05WV  Livingston, York and Adams Group  Architecture/Engineering
#
#    Deal_value  Weighted_amount Date_of_creation      Pitch  \
# 0  320,506.00     2,067,263.70       2020-03-29  Product_2
# 2  359,392.00     2,407,926.40       2019-07-27  Product_1
# 3   76,774.00       468,321.40       2021-01-30  Product_2
# 6  384,356.00     2,709,709.80       2019-11-20  Product_2
# 7  245,205.00     1,642,873.50       2020-12-22  Product_2
#
#             Contact_no             Lead_revenue Fund_category Geography  \
# 0         607.447.7883         50 - 100 Million    Category 2       USA
# ...

# %%
data["Lead_name"]= lab_encod.fit_transform(data["Lead_name"])

# %%
#Count of unique values in Industry column
data["Industry"].unique().shape
# Out:
# (171,)

# %%
#lets label encode them
data["Industry"]= lab_encod.fit_transform(data["Industry"])

# %%
##Count of unique values in Pitch column
data["Pitch"].unique()
# Out:
# array(['Product_2', 'Product_1'], dtype=object)

# %%
data["Pitch"]= lab_encod.fit_transform(data["Pitch"])

# %%
data.head()
# Out:
#    Deal_title  Lead_name  Industry  Deal_value  Weighted_amount  \
# 0  TitleM5DZY       1386       119  320,506.00     2,067,263.70
# 1  TitleKIW18        411        31   39,488.00       240,876.80
# 2  TitleFXSDN        940        56  359,392.00     2,407,926.40
# 3  TitlePSK4Y       1943       114   76,774.00       468,321.40
# 4  Title904GV       3477        46  483,896.00     1,569,883.67
#
#   Date_of_creation  Pitch            Contact_no             Lead_revenue  \
# 0       2020-03-29      1          607.447.7883         50 - 100 Million
# 1       2019-07-10      1          892-938-9493  500 Million - 1 Billion
# 2       2019-07-27      0          538.748.2271  500 Million - 1 Billion
# 3       2021-01-30      1   (692)052-1389x75188  500 Million - 1 Billion
# 4       2019-05-22      1  001-878-814-6134x015         50 - 100 Million
#
#   Fund_category Geography                     Location         POC_name  \
# ...

# %%
#we will drop contact no
#Now lead revenue 
data["Lead_revenue"].unique()
# Out:
# (3,)

# %%
data= pd.get_dummies(data,columns=["Lead_revenue"], drop_first=True)

# %%
data.Fund_category.unique()
# Out:
# array(['Category 2', 'Category 4', 'Category 3', 'Category 1'],
#       dtype=object)

# %%
#label encode Fund_category
data["Fund_category"]= lab_encod.fit_transform(data["Fund_category"])

# %%
#label encode Geography
data["Geography"]= lab_encod.fit_transform(data["Geography"])

# %%
#label encode Location
data.Location.unique().shape
# Out:
# (597,)

# %%
#label encode Location
data["Location"]= lab_encod.fit_transform(data["Location"])

# %%
data.POC_name.unique().shape
#i dont thik POC name is of much use. so we will drop it
# Out:
# (5261,)

# %%
#label encode Designation
data["Designation"]= lab_encod.fit_transform(data["Designation"])

# %%
#i dont thik Lead_POC_email is of much importance we will drop it and contact number, Poc Name
# Out:
# (7007,)

# %%
#how much unique values Hiring_candidate_role have 
data.Hiring_candidate_role.unique().shape
# Out:
# (639,)

# %%
# Hiring_candidate_role as it can be a good feature
#label encode Hiring_candidate_role
data["Hiring_candidate_role"]= lab_encod.fit_transform(data["Hiring_candidate_role"])

# %%
#how much unique values Lead_source have 
data.Lead_source.unique()
# Out:
# array(['Website', 'Others', 'Marketing Event', 'Contact Email'],
#       dtype=object)

# %%
#label encode Lead_source
data["Lead_source"]= lab_encod.fit_transform(data["Lead_source"])

# %%
data.Level_of_meeting.unique()
# Out:
# array(['Level 3', 'Level 1', 'Level 2'], dtype=object)

# %%
#level of meating is an important topic to be considered. thus we will encode tem using get dummies to create feature.
data= pd.get_dummies(data,columns=["Level_of_meeting"], drop_first=True)

# %%
data.Last_lead_update.unique()
# Out:
# array(['No track', 'Did not hear back after Level 1', '?', 'Up-to-date',
#        '2 days back', 'More than 2 weeks', '5 days back',
#        'more than a month', 'Following up but lead not responding',
#        'More than a week back', 'Pending'], dtype=object)

# %%
#first we will replace then ? with unknown 
data["Last_lead_update"] = data["Last_lead_update"].replace("?","Unknown")

# %%
#label encode Last_lead_update
data["Last_lead_update"]= lab_encod.fit_transform(data["Last_lead_update"])

# %%
#Internal_POC consist of 60 unique values this can be useful. Lets label encode them.
data.Internal_POC.unique().shape
# Out:
# (60,)

# %%
#label encode Last_lead_update
data["Internal_POC"]= lab_encod.fit_transform(data["Internal_POC"])

# %%
#we have 6 unique values in the Resource column 
data.Resource.unique().shape
# Out:
# (6,)

# %%
#label encode Last_lead_update
data["Resource"]= lab_encod.fit_transform(data["Resource"])

# %%
# now we have completed all the encoding work lets se the data frame

# %%
data.head()
# Out:
#    Deal_title  Lead_name  Industry  Deal_value  Weighted_amount  \
# 0  TitleM5DZY       1386       119  320,506.00     2,067,263.70
# 1  TitleKIW18        411        31   39,488.00       240,876.80
# 2  TitleFXSDN        940        56  359,392.00     2,407,926.40
# 3  TitlePSK4Y       1943       114   76,774.00       468,321.40
# 4  Title904GV       3477        46  483,896.00     1,569,883.67
#
#   Date_of_creation  Pitch            Contact_no  Fund_category  Geography  \
# 0       2020-03-29      1          607.447.7883              1          1
# 1       2019-07-10      1          892-938-9493              3          0
# 2       2019-07-27      0          538.748.2271              3          1
# 3       2021-01-30      1   (692)052-1389x75188              2          1
# 4       2019-05-22      1  001-878-814-6134x015              2          0
#
#    Location         POC_name  Designation                 Lead_POC_email  \
# ...

# %%
data.to_csv("Encoded.csv", index=False)

# %%
# now lets delete the columns
data.drop(columns=["Lead_name","Contact_no","Lead_POC_email"], inplace=True)

# %%
data.head()
# Out:
#    Deal_title  Industry  Deal_value  Weighted_amount Date_of_creation  Pitch  \
# 0  TitleM5DZY       119  320,506.00     2,067,263.70       2020-03-29      1
# 1  TitleKIW18        31   39,488.00       240,876.80       2019-07-10      1
# 2  TitleFXSDN        56  359,392.00     2,407,926.40       2019-07-27      0
# 3  TitlePSK4Y       114   76,774.00       468,321.40       2021-01-30      1
# 4  Title904GV        46  483,896.00     1,569,883.67       2019-05-22      1
#
#    Fund_category  Geography  Location         POC_name  Designation  \
# 0              1          1       292  Charlene Werner            7
# 1              3          0       457            rakhi            4
# 2              3          1        15   Ariel Hamilton            8
# 3              2          1       372      Erin Wilson            2
# 4              2          0       505           kavita            7
#
#    Hiring_candidate_role  Lead_source  Last_lead_update  Internal_POC  \
# ...

# %%
#now we will drop records with Success_Probability with value over 100.
final_data=data[data["Success_probability"]<100]

# %%
final_data.head()
# Out:
#    Deal_title  Industry  Deal_value  Weighted_amount Date_of_creation  Pitch  \
# 0  TitleM5DZY       119  320,506.00     2,067,263.70       2020-03-29      1
# 1  TitleKIW18        31   39,488.00       240,876.80       2019-07-10      1
# 2  TitleFXSDN        56  359,392.00     2,407,926.40       2019-07-27      0
# 3  TitlePSK4Y       114   76,774.00       468,321.40       2021-01-30      1
# 4  Title904GV        46  483,896.00     1,569,883.67       2019-05-22      1
#
#    Fund_category  Geography  Location         POC_name  Designation  \
# 0              1          1       292  Charlene Werner            7
# 1              3          0       457            rakhi            4
# 2              3          1        15   Ariel Hamilton            8
# 3              2          1       372      Erin Wilson            2
# 4              2          0       505           kavita            7
#
#    Hiring_candidate_role  Lead_source  Last_lead_update  Internal_POC  \
# ...

# %%
final_data.POC_name.unique().shape
# Out:
# (4914,)

# %%
#lets also encode POC_name 
final_data["POC_name"]= lab_encod.fit_transform(final_data["POC_name"])
# Out:
# <ipython-input-302-4b0c868d69ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data["POC_name"]= lab_encod.fit_transform(final_data["POC_name"])

# %%
final_data.head()
# Out:
#    Deal_title  Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# 0  TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# 1  TitleKIW18        31   39,488.00       240,876.80               190      1
# 2  TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# 3  TitlePSK4Y       114   76,774.00       468,321.40               760      1
# 4  Title904GV        46  483,896.00     1,569,883.67               141      1
#
#    Fund_category  Geography  Location  POC_name  Designation  \
# 0              1          1       292       517            7
# 1              3          0       457      4219            4
# 2              3          1        15       240            8
# 3              2          1       372      1069            2
# 4              2          0       505      3675            7
#
#    Hiring_candidate_role  Lead_source  Last_lead_update  Internal_POC  \
# ...

# %%
#data.Date_of_creation.unique().shape
#lets also encode the Date_of_creation
final_data["Date_of_creation"]= lab_encod.fit_transform(final_data["Date_of_creation"])
# Out:
# <ipython-input-305-87621d22c2b5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data["Date_of_creation"]= lab_encod.fit_transform(final_data["Date_of_creation"])

# %%
final_data.head()
# Out:
#    Deal_title  Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# 0  TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# 1  TitleKIW18        31   39,488.00       240,876.80               190      1
# 2  TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# 3  TitlePSK4Y       114   76,774.00       468,321.40               760      1
# 4  Title904GV        46  483,896.00     1,569,883.67               141      1
#
#    Fund_category  Geography  Location  POC_name  Designation  \
# 0              1          1       292       517            7
# 1              3          0       457      4219            4
# 2              3          1        15       240            8
# 3              2          1       372      1069            2
# 4              2          0       505      3675            7
#
#    Hiring_candidate_role  Lead_source  Last_lead_update  Internal_POC  \
# ...

# %%
#set Deal_title as index
final_data.set_index("Deal_title", inplace=True)

# %%
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# TitleKIW18        31   39,488.00       240,876.80               190      1
# TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# TitlePSK4Y       114   76,774.00       468,321.40               760      1
# Title904GV        46  483,896.00     1,569,883.67               141      1
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleM5DZY              1          1       292       517            7
# TitleKIW18              3          0       457      4219            4
# TitleFXSDN              3          1        15       240            8
# TitlePSK4Y              2          1       372      1069            2
# Title904GV              2          0       505      3675            7
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
final_data.columns
# Out:
# Index(['Industry', 'Deal_value', 'Weighted_amount', 'Date_of_creation',
#        'Pitch', 'Fund_category', 'Geography', 'Location', 'POC_name',
#        'Designation', 'Hiring_candidate_role', 'Lead_source',
#        'Last_lead_update', 'Internal_POC', 'Resource', 'Internal_rating',
#        'Success_probability', 'Lead_revenue_50 - 100 Million',
#        'Lead_revenue_500 Million - 1 Billion', 'Level_of_meeting_Level 2',
#        'Level_of_meeting_Level 3'],
#       dtype='object')

# %%
fdata=final_data.reindex(['Industry', 'Deal_value', 'Weighted_amount','Date_of_creation',
       'Pitch', 'Fund_category', 'Geography', 'Location', 'POC_name',
       'Designation', 'Hiring_candidate_role', 'Lead_source',
       'Last_lead_update', 'Internal_POC', 'Resource', 'Internal_rating','Lead_revenue_50 - 100 Million',
       'Lead_revenue_500 Million - 1 Billion', 'Level_of_meeting_Level 2',
       'Level_of_meeting_Level 3','Success_probability'], axis=1)

# %%
fdata.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# TitleKIW18        31   39,488.00       240,876.80               190      1
# TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# TitlePSK4Y       114   76,774.00       468,321.40               760      1
# Title904GV        46  483,896.00     1,569,883.67               141      1
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleM5DZY              1          1       292       517            7
# TitleKIW18              3          0       457      4219            4
# TitleFXSDN              3          1        15       240            8
# TitlePSK4Y              2          1       372      1069            2
# Title904GV              2          0       505      3675            7
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
X=fdata.copy()
X.drop(columns=["Success_probability"], inplace=True)
X.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# TitleKIW18        31   39,488.00       240,876.80               190      1
# TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# TitlePSK4Y       114   76,774.00       468,321.40               760      1
# Title904GV        46  483,896.00     1,569,883.67               141      1
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleM5DZY              1          1       292       517            7
# TitleKIW18              3          0       457      4219            4
# TitleFXSDN              3          1        15       240            8
# TitlePSK4Y              2          1       372      1069            2
# Title904GV              2          0       505      3675            7
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
fdata.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleM5DZY       119  320,506.00     2,067,263.70               453      1
# TitleKIW18        31   39,488.00       240,876.80               190      1
# TitleFXSDN        56  359,392.00     2,407,926.40               207      0
# TitlePSK4Y       114   76,774.00       468,321.40               760      1
# Title904GV        46  483,896.00     1,569,883.67               141      1
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleM5DZY              1          1       292       517            7
# TitleKIW18              3          0       457      4219            4
# TitleFXSDN              3          1        15       240            8
# TitlePSK4Y              2          1       372      1069            2
# Title904GV              2          0       505      3675            7
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
Y=fdata
Y.drop(columns=['Industry', 'Deal_value', 'Weighted_amount','Date_of_creation',
       'Pitch', 'Fund_category', 'Geography', 'Location', 'POC_name',
       'Designation', 'Hiring_candidate_role', 'Lead_source',
       'Last_lead_update', 'Internal_POC', 'Resource', 'Internal_rating','Lead_revenue_50 - 100 Million',
       'Lead_revenue_500 Million - 1 Billion', 'Level_of_meeting_Level 2',
       'Level_of_meeting_Level 3'], inplace=True)
Y.head()
# Out:
#             Success_probability
# Deal_title
# TitleM5DZY                73.60
# TitleKIW18                58.90
# TitleFXSDN                68.80
# TitlePSK4Y                64.50
# Title904GV                62.40

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, random_state=2)

# %%
import xgboost as xgb

# %%
model = xgb.XGBRegressor(n_estimators=150,eval_metric='mae',max_depth=6)
model.fit(X_train, y_train, early_stopping_rounds=35, eval_set=[(X_test, y_test)], verbose=1)
# Out:
# [0]	validation_0-mae:43.37427
# [1]	validation_0-mae:31.78514
# [2]	validation_0-mae:24.35595
# [3]	validation_0-mae:19.14029
# [4]	validation_0-mae:15.51603
# [5]	validation_0-mae:12.93877
# [6]	validation_0-mae:11.16742
# [7]	validation_0-mae:9.94884
# [8]	validation_0-mae:9.03790
# [9]	validation_0-mae:8.42927
# [10]	validation_0-mae:8.00132
# [11]	validation_0-mae:7.73434
# [12]	validation_0-mae:7.54235
# [13]	validation_0-mae:7.40711
# [14]	validation_0-mae:7.32424
# [15]	validation_0-mae:7.27113
# [16]	validation_0-mae:7.24728
# [17]	validation_0-mae:7.24329
# [18]	validation_0-mae:7.25392
# [19]	validation_0-mae:7.25525
# [20]	validation_0-mae:7.29057
# [21]	validation_0-mae:7.29308
# [22]	validation_0-mae:7.30279
# [23]	validation_0-mae:7.30006
# [24]	validation_0-mae:7.29427
# [25]	validation_0-mae:7.35021
# [26]	validation_0-mae:7.36814
# [27]	validation_0-mae:7.37947
# [28]	validation_0-mae:7.37974
# [29]	validation_0-mae:7.39530
# [30]	validation_0-mae:7.40354
# ...

# %% [markdown]
# Refer para
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='mae', gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
ypred=model.predict(X_test)

# %%
from sklearn import metrics
score=max(0,100-np.sqrt(metrics.mean_squared_error(y_test,ypred)))
print(score)
# Out:
# 86.873697030073

# %%
X_train.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleU5I69        62  226,834.00     1,485,762.70               169      0
# TitleC1JWL         0  202,313.00     1,183,531.05               694      0
# TitleWII3C        66  115,699.00       682,624.10               220      0
# Title6AV9M         2   98,010.00       656,667.00                77      0
# TitleOVF7D        31  461,058.00     3,042,982.80               558      1
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleU5I69              2          0        18      3998            6
# TitleC1JWL              2          0       113      3205            3
# TitleWII3C              2          0       377      3702            0
# Title6AV9M              3          0       288      3246            9
# TitleOVF7D              2          1       249        96            7
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %% [markdown]
# Now test The data

# %%
tdata=pd.read_csv("final_test1.csv")
tdata.head()
# Out:
#    Deal_title  Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# 0  TitleAD16O        55  200,988.00     1,556,916.67               427      0
# 1  TitleOW6CR        30  409,961.00     2,541,758.20               698      0
# 2  TitleVVJQ5        13  434,433.00     3,041,031.00               519      0
# 3  TitleUS8NA        69  218,952.00     1,521,716.40               385      1
# 4  Title5VGWW        95  392,835.00     2,455,218.75               610      0
#
#    Fund_category  Geography  Location  POC_name  Designation  \
# 0              3          0        68      1666            4
# 1              2          1       122       220            2
# 2              0          1       409        44            5
# 3              0          0        48      1583            1
# 4              2          1       522       901            2
#
#    Hiring_candidate_role  Lead_source  Last_lead_update  Internal_POC  \
# ...

# %%
tdata.set_index("Deal_title", inplace=True)
tdata.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleAD16O        55  200,988.00     1,556,916.67               427      0
# TitleOW6CR        30  409,961.00     2,541,758.20               698      0
# TitleVVJQ5        13  434,433.00     3,041,031.00               519      0
# TitleUS8NA        69  218,952.00     1,521,716.40               385      1
# Title5VGWW        95  392,835.00     2,455,218.75               610      0
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleAD16O              3          0        68      1666            4
# TitleOW6CR              2          1       122       220            2
# TitleVVJQ5              0          1       409        44            5
# TitleUS8NA              0          0        48      1583            1
# Title5VGWW              2          1       522       901            2
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
test_result=model.predict(tdata)

# %%
tdata["Success_probability"]=test_result

# %%
tdata.head()
# Out:
#             Industry  Deal_value  Weighted_amount  Date_of_creation  Pitch  \
# Deal_title
# TitleAD16O        55  200,988.00     1,556,916.67               427      0
# TitleOW6CR        30  409,961.00     2,541,758.20               698      0
# TitleVVJQ5        13  434,433.00     3,041,031.00               519      0
# TitleUS8NA        69  218,952.00     1,521,716.40               385      1
# Title5VGWW        95  392,835.00     2,455,218.75               610      0
#
#             Fund_category  Geography  Location  POC_name  Designation  \
# Deal_title
# TitleAD16O              3          0        68      1666            4
# TitleOW6CR              2          1       122       220            2
# TitleVVJQ5              0          1       409        44            5
# TitleUS8NA              0          0        48      1583            1
# Title5VGWW              2          1       522       901            2
#
#             Hiring_candidate_role  Lead_source  Last_lead_update  \
# ...

# %%
#create a submission file
tdata.columns
# Out:
# Index(['Industry', 'Deal_value', 'Weighted_amount', 'Date_of_creation',
#        'Pitch', 'Fund_category', 'Geography', 'Location', 'POC_name',
#        'Designation', 'Hiring_candidate_role', 'Lead_source',
#        'Last_lead_update', 'Internal_POC', 'Resource', 'Internal_rating',
#        'Lead_revenue_50 - 100 Million', 'Lead_revenue_500 Million - 1 Billion',
#        'Level_of_meeting_Level 2', 'Level_of_meeting_Level 3',
#        'Success_probability'],
#       dtype='object')

# %%
tdata.drop(columns=['Industry', 'Deal_value', 'Weighted_amount', 'Date_of_creation',
       'Pitch', 'Fund_category', 'Geography', 'Location', 'POC_name',
       'Designation', 'Hiring_candidate_role', 'Lead_source',
       'Last_lead_update', 'Internal_POC', 'Resource', 'Internal_rating',
       'Lead_revenue_50 - 100 Million', 'Lead_revenue_500 Million - 1 Billion',
       'Level_of_meeting_Level 2', 'Level_of_meeting_Level 3'], inplace=True)

# %%
tdata.to_csv("Submission_file1.csv", index=True)
